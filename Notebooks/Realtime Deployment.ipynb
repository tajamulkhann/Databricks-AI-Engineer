# %%
import requests
import json
import os

# Setup
DATABRICKS_TOKEN = '' # or set manually
#ENDPOINT_URL = ""
ENDPOINT_URL = ""

# Sample input (depends on your model)
input_data = {
    "prompt": "Summarize: Databricks is a powerful data platform used for machine learning and data engineering."}


# Make request
headers = {
    "Authorization": f"Bearer {DATABRICKS_TOKEN}",
    "Content-Type": "application/json"
}

response = requests.post(ENDPOINT_URL, headers=headers, data=json.dumps(input_data))

# Output
print("Prediction:", response.json())
# Out:
# Prediction: ['Summarize: Databricks is a powerful data platform used for machine learning and data engineering. It is based on a strong data platform that can be used in machine learning, data engineering, and machine learning.']
